# %% [markdown]
# # Pointnet - Classification
#
# This is a re-imeplmentation of poinnet.
# There are some code are the same with the original code, such as provide etc..

# %%
import math
import h5py
import numpy as np
import tensorflow as tf
import socket
import importlib
import os
import sys

BASE_DIR = '/notebooks/'
sys.path.append(BASE_DIR)
sys.path.append(os.path.join(BASE_DIR, 'models'))
sys.path.append(os.path.join(BASE_DIR, 'utils'))
import cls_provider as provider
import pointnet_cls as MODEL
# import tf_util
# import pointnet_cls

# %%
BATCH_SIZE = 32
NUM_POINT = 1024
MAX_EPOCH = 250
BASE_LEARNING_RATE = 0.001
GPU_INDEX = 0
MOMENTUM = 0.9
OPTIMIZER = 'adam'
DECAY_STEP = 200000
DECAY_RATE = 0.7
LOG_DIR = 'logs'


MAX_NUM_POINT = 2048
NUM_CLASSES = 40

BN_INIT_DECAY = 0.5
BN_DECAY_DECAY_RATE = 0.5
BN_DECAY_DECAY_STEP = float(DECAY_STEP)
BN_DECAY_CLIP = 0.99

# %% [markdown]
# ## Create log

# %%
if not os.path.exists(LOG_DIR): os.mkdir(LOG_DIR)
LOG_FOUT = open(os.path.join(LOG_DIR, 'log_train.txt'), 'w')


def log_string(out_str):
    LOG_FOUT.write(out_str+'\n')
    LOG_FOUT.flush()
    print(out_str)

# %% [markdown]
# ### ModelNet40 train/test split

# %%
# ModelNet40 official train/test split
TRAIN_FILES = provider.getDataFiles( \
    os.path.join(BASE_DIR, 'data/modelnet40_ply_hdf5_2048/train_files.txt'))
TEST_FILES = provider.getDataFiles(\
    os.path.join(BASE_DIR, 'data/modelnet40_ply_hdf5_2048/test_files.txt'))

# %% [markdown]
# #### Train rate/ decay

# %%
def get_learning_rate(batch):
    learning_rate = tf.train.exponential_decay(
                        BASE_LEARNING_RATE,  # Base learning rate.
                        batch * BATCH_SIZE,  # Current index into the dataset.
                        DECAY_STEP,          # Decay step.
                        DECAY_RATE,          # Decay rate.
                        staircase=True)
    learning_rate = tf.maximum(learning_rate, 0.00001) # CLIP THE LEARNING RATE!
    return learning_rate        

def get_bn_decay(batch):
    bn_momentum = tf.train.exponential_decay(
                      BN_INIT_DECAY,
                      batch*BATCH_SIZE,
                      BN_DECAY_DECAY_STEP,
                      BN_DECAY_DECAY_RATE,
                      staircase=True)
    bn_decay = tf.minimum(BN_DECAY_CLIP, 1 - bn_momentum)
    return bn_decay

# %% [markdown]
# ### Define graph

# %%
def create_graph():
    pointclouds_pl, labels_pl = MODEL.placeholder_inputs(BATCH_SIZE, NUM_POINT)
    is_training_pl = tf.placeholder(tf.bool, shape=())
    print(is_training_pl)

    # Note the global_step=batch parameter to minimize. 
    # That tells the optimizer to helpfully increment the 'batch' parameter for you every time it trains.
    batch = tf.Variable(0)
    bn_decay = get_bn_decay(batch)
    tf.summary.scalar('bn_decay', bn_decay)

    # Get model and loss 
    pred, end_points = MODEL.get_model(pointclouds_pl, is_training_pl, bn_decay=bn_decay)
    loss = MODEL.get_loss(pred, labels_pl, end_points)
    tf.summary.scalar('loss', loss)

    correct = tf.equal(tf.argmax(pred, 1), tf.to_int64(labels_pl))
    accuracy = tf.reduce_sum(tf.cast(correct, tf.float32)) / float(BATCH_SIZE)
    tf.summary.scalar('accuracy', accuracy)

    # Get training operator
    learning_rate = get_learning_rate(batch)
    tf.summary.scalar('learning_rate', learning_rate)
    if OPTIMIZER == 'momentum':
        optimizer = tf.train.MomentumOptimizer(learning_rate, momentum=MOMENTUM)
    elif OPTIMIZER == 'adam':
        optimizer = tf.train.AdamOptimizer(learning_rate)
    train_op = optimizer.minimize(loss, global_step=batch)

    # Add ops to save and restore all the variables.
    saver = tf.train.Saver()
    
    return {
        'pointclouds_pl':pointclouds_pl,
        'labels_pl':labels_pl,
        'is_training_pl':is_training_pl,
        'train_op':train_op,
        'batch':batch,
        'bn_decay':bn_decay,
        'pred':pred,
        'end_points':end_points,
        'loss':loss,
        'correct':correct,
        'learning_rate':learning_rate,
        'train_op':train_op,
        'saver':saver
    }

# %% [markdown]
# ### Train Loop

# %%
def train_one_epoch(sess, ops, train_writer):
    """ ops: dict mapping from string to tf ops """
    is_training = True
    
    # Shuffle train files
    train_file_idxs = np.arange(0, len(TRAIN_FILES))
    np.random.shuffle(train_file_idxs)
    
    for fn in range(len(TRAIN_FILES)):
        log_string('----' + str(fn) + '-----')
        current_data, current_label = provider.loadDataFile(TRAIN_FILES[train_file_idxs[fn]])
        current_data = current_data[:,0:NUM_POINT,:]
        current_data, current_label, _ = provider.shuffle_data(current_data, np.squeeze(current_label))            
        current_label = np.squeeze(current_label)
        
        file_size = current_data.shape[0]
        num_batches = file_size // BATCH_SIZE
        
        total_correct = 0
        total_seen = 0
        loss_sum = 0
       
        for batch_idx in range(num_batches):
            start_idx = batch_idx * BATCH_SIZE
            end_idx = (batch_idx+1) * BATCH_SIZE
            
            # Augment batched point clouds by rotation and jittering
            rotated_data = provider.rotate_point_cloud(current_data[start_idx:end_idx, :, :])
            jittered_data = provider.jitter_point_cloud(rotated_data)
            feed_dict = {ops['pointclouds_pl']: jittered_data,
                         ops['labels_pl']: current_label[start_idx:end_idx],
                         ops['is_training_pl']: is_training,}
            summary, step, _, loss_val, pred_val = sess.run([ops['merged'], ops['step'],
                ops['train_op'], ops['loss'], ops['pred']], feed_dict=feed_dict)
            train_writer.add_summary(summary, step)
            pred_val = np.argmax(pred_val, 1)
            correct = np.sum(pred_val == current_label[start_idx:end_idx])
            total_correct += correct
            total_seen += BATCH_SIZE
            loss_sum += loss_val
        
        log_string('mean loss: %f' % (loss_sum / float(num_batches)))
        log_string('accuracy: %f' % (total_correct / float(total_seen)))

# %%
def eval_one_epoch(sess, ops, test_writer):
    """ ops: dict mapping from string to tf ops """
    is_training = False
    total_correct = 0
    total_seen = 0
    loss_sum = 0
    total_seen_class = [0 for _ in range(NUM_CLASSES)]
    total_correct_class = [0 for _ in range(NUM_CLASSES)]
    
    for fn in range(len(TEST_FILES)):
        log_string('----' + str(fn) + '-----')
        current_data, current_label = provider.loadDataFile(TEST_FILES[fn])
        current_data = current_data[:,0:NUM_POINT,:]
        current_label = np.squeeze(current_label)
        
        file_size = current_data.shape[0]
        num_batches = file_size // BATCH_SIZE
        
        for batch_idx in range(num_batches):
            start_idx = batch_idx * BATCH_SIZE
            end_idx = (batch_idx+1) * BATCH_SIZE

            feed_dict = {ops['pointclouds_pl']: current_data[start_idx:end_idx, :, :],
                         ops['labels_pl']: current_label[start_idx:end_idx],
                         ops['is_training_pl']: is_training}
            summary, step, loss_val, pred_val = sess.run([ops['merged'], ops['step'],
                ops['loss'], ops['pred']], feed_dict=feed_dict)
            pred_val = np.argmax(pred_val, 1)
            correct = np.sum(pred_val == current_label[start_idx:end_idx])
            total_correct += correct
            total_seen += BATCH_SIZE
            loss_sum += (loss_val*BATCH_SIZE)
            for i in range(start_idx, end_idx):
                l = current_label[i]
                total_seen_class[l] += 1
                total_correct_class[l] += (pred_val[i-start_idx] == l)
            
    log_string('eval mean loss: %f' % (loss_sum / float(total_seen)))
    log_string('eval accuracy: %f'% (total_correct / float(total_seen)))
    log_string('eval avg class acc: %f' % (np.mean(np.array(total_correct_class)/np.array(total_seen_class,dtype=np.float))))

# %%
with tf.device('/gpu:'+str(GPU_INDEX)):
    sess_graph = create_graph()

    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    config.allow_soft_placement = True
    config.log_device_placement = False
    sess = tf.Session(config=config)

    # Add summary writers
    #merged = tf.merge_all_summaries()
    merged = tf.summary.merge_all()
    train_writer = tf.summary.FileWriter(os.path.join(LOG_DIR, 'train'),
                              sess.graph)
    test_writer = tf.summary.FileWriter(os.path.join(LOG_DIR, 'test'))

    # Init variables
    init = tf.global_variables_initializer()
    # To fix the bug introduced in TF 0.12.1 as in
    # http://stackoverflow.com/questions/41543774/invalidargumenterror-for-tensor-bool-tensorflow-0-12-1
    #sess.run(init)
    sess.run(init, {sess_graph['is_training_pl']: True})

    ops = {'pointclouds_pl': sess_graph['pointclouds_pl'],
           'labels_pl': sess_graph['labels_pl'],
           'is_training_pl': sess_graph['is_training_pl'],
           'pred': sess_graph['pred'],
           'loss': sess_graph['loss'],
           'train_op': sess_graph['train_op'],
           'merged': merged,
           'step': sess_graph['batch']}

    for epoch in range(MAX_EPOCH):
        log_string('**** EPOCH %03d ****' % (epoch))
        sys.stdout.flush()

        train_one_epoch(sess, ops, train_writer)
        eval_one_epoch(sess, ops, test_writer)

        # Save the variables to disk.
        if epoch % 10 == 0:
            save_path = sess_graph['saver'].save(sess, os.path.join(LOG_DIR, "model.ckpt"))
            log_string("Model saved in file: %s" % save_path)
# Out:
# Tensor("Placeholder_2:0", shape=(), dtype=bool, device=/device:GPU:0)
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.
# INFO:tensorflow:Summary name classify loss is illegal; using classify_loss instead.
# INFO:tensorflow:Summary name mat loss is illegal; using mat_loss instead.
# **** EPOCH 000 ****
# ----0-----
# mean loss: 4.004907
# accuracy: 0.179534
# ----1-----
# mean loss: 2.837159
# accuracy: 0.322754
# ----2-----
# mean loss: 2.350129
# accuracy: 0.383301
# ----3-----
# mean loss: 2.103691
# accuracy: 0.441895
# ----4-----
# mean loss: 1.930095
# accuracy: 0.474609
# ----0-----
# ----1-----
# eval mean loss: 2.139408
# eval accuracy: 0.447646
# eval avg class acc: 0.402099
# Model saved in file: logs/model.ckpt
# **** EPOCH 001 ****
# ----0-----
# mean loss: 1.763787
# accuracy: 0.507812
# ----1-----
# mean loss: 1.656303
# accuracy: 0.534926
# ----2-----
# mean loss: 1.635950
# accuracy: 0.540039
# ----3-----
# mean loss: 1.489892
# accuracy: 0.577148
# ----4-----
# mean loss: 1.399502
# accuracy: 0.601562
# ----0-----
# ----1-----
# eval mean loss: 1.349742
# eval accuracy: 0.588474
# eval avg class acc: 0.515652
# **** EPOCH 002 ****
# ----0-----
# mean loss: 1.316391
# accuracy: 0.602051
# ----1-----
# mean loss: 1.323470
# accuracy: 0.618652
# ----2-----
# mean loss: 1.608438
# accuracy: 0.570801
# ----3-----
# mean loss: 1.656475
# accuracy: 0.522672
# ----4-----
# mean loss: 1.421430
# accuracy: 0.584961
# ----0-----
# ----1-----
# eval mean loss: 1.317572
# eval accuracy: 0.611607
# eval avg class acc: 0.566684
# **** EPOCH 003 ****
# ----0-----
# mean loss: 1.218334
# accuracy: 0.645508
# ----1-----
# mean loss: 1.224096
# accuracy: 0.633301
# ----2-----
# mean loss: 1.133428
# accuracy: 0.656250
# ----3-----
# mean loss: 1.092831
# accuracy: 0.681641
# ----4-----
# mean loss: 1.002388
# accuracy: 0.697304
# ----0-----
# ----1-----
# eval mean loss: 1.165930
# eval accuracy: 0.674513
# eval avg class acc: 0.612168
# **** EPOCH 004 ****
# ----0-----
# mean loss: 1.083794
# accuracy: 0.679199
# ----1-----
# mean loss: 1.003814
# accuracy: 0.690918
# ----2-----
# mean loss: 0.918641
# accuracy: 0.716912
# ----3-----
# mean loss: 0.991035
# accuracy: 0.702637
# ----4-----
# mean loss: 1.015400
# accuracy: 0.691406
# ----0-----
# ----1-----
# eval mean loss: 0.903308
# eval accuracy: 0.725649
# eval avg class acc: 0.673467
# **** EPOCH 005 ****
# ----0-----
# mean loss: 0.940023
# accuracy: 0.719727
# ----1-----
# mean loss: 0.916154
# accuracy: 0.720703
# ----2-----
# mean loss: 0.919408
# accuracy: 0.726103
# ----3-----
# mean loss: 0.915130
# accuracy: 0.729980
# ----4-----
# mean loss: 0.875845
# accuracy: 0.734375
# ----0-----
# ----1-----
# eval mean loss: 0.826625
# eval accuracy: 0.748782
# eval avg class acc: 0.686529
# **** EPOCH 006 ****
# ----0-----
# mean loss: 0.881893
# accuracy: 0.734863
# ----1-----
# mean loss: 0.876241
# accuracy: 0.736816
# ----2-----
# mean loss: 1.066130
# accuracy: 0.695801
# ----3-----
# mean loss: 1.017141
# accuracy: 0.683824
# ----4-----
# mean loss: 0.942054
# accuracy: 0.701172
# ----0-----
# ----1-----
# eval mean loss: 0.834076
# eval accuracy: 0.740666
# eval avg class acc: 0.661250
# **** EPOCH 007 ****
# ----0-----
# mean loss: 0.844363
# accuracy: 0.739258
# ----1-----
# mean loss: 0.845103
# accuracy: 0.736816
# ----2-----
# mean loss: 0.822158
# accuracy: 0.738281
# ----3-----
# mean loss: 0.872487
# accuracy: 0.733398
# ----4-----
# mean loss: 0.775530
# accuracy: 0.769608
# ----0-----
# ----1-----
# eval mean loss: 0.741064
# eval accuracy: 0.775568
# eval avg class acc: 0.716187
# **** EPOCH 008 ****
# ----0-----
# mean loss: 0.772013
# accuracy: 0.766113
# ----1-----
# mean loss: 0.819317
# accuracy: 0.754883
# ----2-----
# mean loss: 0.733733
# accuracy: 0.773897
# ----3-----
# mean loss: 0.778487
# accuracy: 0.756836
# ----4-----
# mean loss: 0.804769
# accuracy: 0.744141
# ----0-----
# ----1-----
# eval mean loss: 0.835801
# eval accuracy: 0.752841
# eval avg class acc: 0.705065
# **** EPOCH 009 ****
# ----0-----
# mean loss: 0.774354
# accuracy: 0.760254
# ----1-----
# mean loss: 0.757601
# accuracy: 0.763184
# ----2-----
# mean loss: 0.768403
# accuracy: 0.756348
# ----3-----
# mean loss: 0.757895
# accuracy: 0.773926
# ----4-----
# mean loss: 0.693686
# accuracy: 0.778799
# ----0-----
# ----1-----
# eval mean loss: 0.760453
# eval accuracy: 0.755276
# eval avg class acc: 0.703835
# **** EPOCH 010 ****
# ----0-----
# mean loss: 0.737514
# accuracy: 0.769043
# ----1-----
# mean loss: 0.715823
# accuracy: 0.786133
# ----2-----
# mean loss: 0.669204
# accuracy: 0.783088
# ----3-----
# mean loss: 0.733507
# accuracy: 0.771484
# ----4-----
# mean loss: 0.724531
# accuracy: 0.774902
# ----0-----
# ----1-----
# eval mean loss: 0.770141
# eval accuracy: 0.772321
# eval avg class acc: 0.731554
# Model saved in file: logs/model.ckpt
# **** EPOCH 011 ****
# ----0-----
# mean loss: 0.725250
# accuracy: 0.777344
# ----1-----
# mean loss: 0.620667
# accuracy: 0.802696
# ----2-----
# mean loss: 0.671048
# accuracy: 0.786621
# ----3-----
# mean loss: 0.726792
# accuracy: 0.780273
# ----4-----
# mean loss: 0.707687
# accuracy: 0.784668
# ----0-----
# ----1-----
# eval mean loss: 0.675571
# eval accuracy: 0.799107
# eval avg class acc: 0.741863
# **** EPOCH 012 ****
# ----0-----
# mean loss: 0.691334
# accuracy: 0.784180
# ----1-----
# mean loss: 0.678572
# accuracy: 0.793945
# ----2-----
# mean loss: 0.679759
# accuracy: 0.784180
# ----3-----
# mean loss: 0.655065
# accuracy: 0.795898
# ----4-----
# mean loss: 0.644318
# accuracy: 0.800245
# ----0-----
# ----1-----
# eval mean loss: 0.700215
# eval accuracy: 0.785714
# eval avg class acc: 0.742475
# **** EPOCH 013 ****
# ----0-----
# mean loss: 0.702160
# accuracy: 0.776348
# ----1-----
# mean loss: 0.708737
# accuracy: 0.780273
# ----2-----
# mean loss: 0.733801
# accuracy: 0.768066
# ----3-----
# mean loss: 0.715290
# accuracy: 0.778320
# ----4-----
# mean loss: 0.722529
# accuracy: 0.785645
# ----0-----
# ----1-----
# eval mean loss: 0.737777
# eval accuracy: 0.772321
# eval avg class acc: 0.712178
# **** EPOCH 014 ****
# ----0-----
# mean loss: 0.616675
# accuracy: 0.812988
# ----1-----
# mean loss: 0.667174
# accuracy: 0.790039
# ----2-----
# mean loss: 0.625022
# accuracy: 0.800781
# ----3-----
# mean loss: 0.654060
# accuracy: 0.791992
# ----4-----
# mean loss: 0.574156
# accuracy: 0.814951
# ----0-----
# ----1-----
# eval mean loss: 0.623433
# eval accuracy: 0.802354
# eval avg class acc: 0.756891
# **** EPOCH 015 ****
# ----0-----
# mean loss: 0.629558
# accuracy: 0.805664
# ----1-----
# mean loss: 0.638789
# accuracy: 0.798828
# ----2-----
# mean loss: 0.633304
# accuracy: 0.810547
# ----3-----
# mean loss: 0.639492
# accuracy: 0.798828
# ----4-----
# mean loss: 0.583790
# accuracy: 0.815564
# ----0-----
# ----1-----
# eval mean loss: 0.649414
# eval accuracy: 0.801948
# eval avg class acc: 0.761216
# **** EPOCH 016 ****
# ----0-----
# mean loss: 0.617174
# accuracy: 0.809570
# ----1-----
# mean loss: 0.610408
# accuracy: 0.807617
# ----2-----
# mean loss: 0.619984
# accuracy: 0.804688
# ----3-----
# mean loss: 0.568655
# accuracy: 0.826593
# ----4-----
# mean loss: 0.620341
# accuracy: 0.794434
# ----0-----
# ----1-----
# eval mean loss: 0.664826
# eval accuracy: 0.799919
# eval avg class acc: 0.761522
# **** EPOCH 017 ****
# ----0-----
# mean loss: 0.529995
# accuracy: 0.828431
# ----1-----
# mean loss: 0.597788
# accuracy: 0.809570
# ----2-----
# mean loss: 0.633508
# accuracy: 0.795898
# ----3-----
# mean loss: 0.666701
# accuracy: 0.791016
# ----4-----
# mean loss: 0.604682
# accuracy: 0.821777
# ----0-----
# ----1-----
# eval mean loss: 0.593924
# eval accuracy: 0.818182
# eval avg class acc: 0.761277
# **** EPOCH 018 ****
# ----0-----
# mean loss: 0.610899
# accuracy: 0.806641
# ----1-----
# mean loss: 0.572382
# accuracy: 0.817871
# ----2-----
# mean loss: 0.611169
# accuracy: 0.811035
# ----3-----
# mean loss: 0.569300
# accuracy: 0.817402
# ----4-----
# mean loss: 0.630117
# accuracy: 0.800781
# ----0-----
# ----1-----
# eval mean loss: 0.610456
# eval accuracy: 0.817776
# eval avg class acc: 0.765057
# **** EPOCH 019 ****
# ----0-----
# mean loss: 0.552639
# accuracy: 0.822304
# ----1-----
# mean loss: 0.586807
# accuracy: 0.817871
# ----2-----
# mean loss: 0.555262
# accuracy: 0.828125
# ----3-----
# mean loss: 0.618376
# accuracy: 0.818848
# ----4-----
# mean loss: 0.624415
# accuracy: 0.812500
# ----0-----
# ----1-----
# eval mean loss: 0.664363
# eval accuracy: 0.804383
# eval avg class acc: 0.756896
# **** EPOCH 020 ****
# ----0-----
# mean loss: 0.556897
# accuracy: 0.824707
# ----1-----
# mean loss: 0.609356
# accuracy: 0.817871
# ----2-----
# mean loss: 0.539032
# accuracy: 0.825195
# ----3-----
# mean loss: 0.532792
# accuracy: 0.835784
# ----4-----
# mean loss: 0.503626
# accuracy: 0.838379
# ----0-----
# ----1-----
# eval mean loss: 0.581461
# eval accuracy: 0.825487
# eval avg class acc: 0.778552
# Model saved in file: logs/model.ckpt
# **** EPOCH 021 ****
# ----0-----
# mean loss: 0.462901
# accuracy: 0.846191
# ----1-----
# mean loss: 0.514229
# accuracy: 0.835938
# ----2-----
# mean loss: 0.484363
# accuracy: 0.839844
# ----3-----
# mean loss: 0.471535
# accuracy: 0.847426
# ----4-----
# mean loss: 0.568689
# accuracy: 0.828125
# ----0-----
# ----1-----
# eval mean loss: 0.654643
# eval accuracy: 0.798295
# eval avg class acc: 0.751677
# **** EPOCH 022 ****
# ----0-----
# mean loss: 0.558525
# accuracy: 0.816406
# ----1-----
# mean loss: 0.516478
# accuracy: 0.833008
# ----2-----
# mean loss: 0.474366
# accuracy: 0.843750
# ----3-----
# mean loss: 0.503441
# accuracy: 0.834961
# ----4-----
# mean loss: 0.515280
# accuracy: 0.832031
# ----0-----
# ----1-----
# eval mean loss: 0.589299
# eval accuracy: 0.816153
# eval avg class acc: 0.778860
# **** EPOCH 023 ****
# ----0-----
# mean loss: 0.457376
# accuracy: 0.852539
# ----1-----
# mean loss: 0.481170
# accuracy: 0.845703
# ----2-----
# mean loss: 0.491991
# accuracy: 0.847168
# ----3-----
# mean loss: 0.446293
# accuracy: 0.857843
# ----4-----
# mean loss: 0.499404
# accuracy: 0.833496
# ----0-----
# ----1-----
# eval mean loss: 0.567024
# eval accuracy: 0.834821
# eval avg class acc: 0.793276
# **** EPOCH 024 ****
# ----0-----
# mean loss: 0.464742
# accuracy: 0.845703
# ----1-----
# mean loss: 0.459930
# accuracy: 0.853027
# ----2-----
# mean loss: 0.485571
# accuracy: 0.837402
# ----3-----
# mean loss: 0.456273
# accuracy: 0.853027
# ----4-----
# mean loss: 0.456685
# accuracy: 0.856005
# ----0-----
# ----1-----
# eval mean loss: 0.574957
# eval accuracy: 0.821834
# eval avg class acc: 0.787597
# **** EPOCH 025 ****
# ----0-----
# mean loss: 0.380030
# accuracy: 0.867647
# ----1-----
# mean loss: 0.489419
# accuracy: 0.835938
# ----2-----
# mean loss: 0.489750
# accuracy: 0.838379
# ----3-----
# mean loss: 0.481735
# accuracy: 0.852539
# ----4-----
# mean loss: 0.471428
# accuracy: 0.854492
# ----0-----
# ----1-----
# eval mean loss: 0.546462
# eval accuracy: 0.837256
# eval avg class acc: 0.805153
# **** EPOCH 026 ****
# ----0-----
# mean loss: 0.468348
# accuracy: 0.845703
# ----1-----
# mean loss: 0.463678
# accuracy: 0.849609
# ----2-----
# mean loss: 0.432140
# accuracy: 0.862132
# ----3-----
# mean loss: 0.482051
# accuracy: 0.844727
# ----4-----
# mean loss: 0.476197
# accuracy: 0.840820
# ----0-----
# ----1-----
# eval mean loss: 0.560591
# eval accuracy: 0.838880
# eval avg class acc: 0.796812
# **** EPOCH 027 ****
# ----0-----
# mean loss: 0.421231
# accuracy: 0.863971
# ----1-----
# mean loss: 0.421127
# accuracy: 0.862793
# ----2-----
# mean loss: 0.430083
# accuracy: 0.858398
# ----3-----
# mean loss: 0.464200
# accuracy: 0.850098
# ----4-----
# mean loss: 0.459556
# accuracy: 0.854492
# ----0-----
# ----1-----
# eval mean loss: 0.548349
# eval accuracy: 0.831169
# eval avg class acc: 0.784723
# **** EPOCH 028 ****
# ----0-----
# mean loss: 0.479376
# accuracy: 0.837891
# ----1-----
# mean loss: 0.443913
# accuracy: 0.856005
# ----2-----
# mean loss: 0.457990
# accuracy: 0.853027
# ----3-----
# mean loss: 0.442948
# accuracy: 0.847656
# ----4-----
# mean loss: 0.446312
# accuracy: 0.852539
# ----0-----
# ----1-----
# eval mean loss: 0.525057
# eval accuracy: 0.845779
# eval avg class acc: 0.810087
# **** EPOCH 029 ****
# ----0-----
# mean loss: 0.400488
# accuracy: 0.865809
# ----1-----
# mean loss: 0.440715
# accuracy: 0.855957
# ----2-----
# mean loss: 0.472943
# accuracy: 0.849121
# ----3-----
# mean loss: 0.428550
# accuracy: 0.861328
# ----4-----
# mean loss: 0.457393
# accuracy: 0.857422
# ----0-----
# ----1-----
# eval mean loss: 0.514315
# eval accuracy: 0.844968
# eval avg class acc: 0.801442
# **** EPOCH 030 ****
# ----0-----
# mean loss: 0.416951
# accuracy: 0.863971
# ----1-----
# mean loss: 0.446179
# accuracy: 0.861328
# ----2-----
# mean loss: 0.432132
# accuracy: 0.867676
# ----3-----
# mean loss: 0.448480
# accuracy: 0.848145
# ----4-----
# mean loss: 0.443077
# accuracy: 0.858887
# ----0-----
# ----1-----
# eval mean loss: 0.501178
# eval accuracy: 0.848214
# eval avg class acc: 0.818608
# Model saved in file: logs/model.ckpt
# **** EPOCH 031 ****
# ----0-----
# mean loss: 0.387386
# accuracy: 0.869141
# ----1-----
# mean loss: 0.406146
# accuracy: 0.867034
# ----2-----
# mean loss: 0.437297
# accuracy: 0.860840
# ----3-----
# mean loss: 0.449017
# accuracy: 0.849609
# ----4-----
# mean loss: 0.440399
# accuracy: 0.855957
# ----0-----
# ----1-----
# eval mean loss: 0.537444
# eval accuracy: 0.833604
# eval avg class acc: 0.810375
# **** EPOCH 032 ****
# ----0-----
# mean loss: 0.426396
# accuracy: 0.858398
# ----1-----
# mean loss: 0.387739
# accuracy: 0.878064
# ----2-----
# mean loss: 0.432396
# accuracy: 0.855957
# ----3-----
# mean loss: 0.432844
# accuracy: 0.862305
# ----4-----
# mean loss: 0.428389
# accuracy: 0.858398
# ----0-----
# ----1-----
# eval mean loss: 0.512796
# eval accuracy: 0.847808
# eval avg class acc: 0.793786
# **** EPOCH 033 ****
# ----0-----
# mean loss: 0.397950
# accuracy: 0.865196
# ----1-----
# mean loss: 0.413216
# accuracy: 0.862305
# ----2-----
# mean loss: 0.418800
# accuracy: 0.870605
# ----3-----
# mean loss: 0.423614
# accuracy: 0.870117
# ----4-----
# mean loss: 0.458268
# accuracy: 0.854492
# ----0-----
# ----1-----
# eval mean loss: 0.519429
# eval accuracy: 0.848620
# eval avg class acc: 0.807630
# **** EPOCH 034 ****
# ----0-----

# %%
LOG_FOUT.close()
